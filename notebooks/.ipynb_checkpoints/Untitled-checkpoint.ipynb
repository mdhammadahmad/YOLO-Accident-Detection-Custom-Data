# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11n.pt")

# %%
train_results = model.train(
    data = "C:/Users/shell/OneDrive/Desktop/accident_detection/dataset/data.yaml",
    epochs = 5,
    imgsz = 640,
    device = 0,
    project="C:/Users/shell/OneDrive/Desktop/accident_detection/runs",
    name="accident_train_v1"
)
# Out:
# Ultralytics 8.4.13  Python-3.11.1 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))

# %%
import os
os.getcwd()

# %%
import os
os.listdir(r"C:\Users\shell\OneDrive\Desktop\accident_detection\dataset\labels\val")
# Out:
# ['test10_54.txt.txt',
#  'test13_18.txt.txt',
#  'test13_20.txt.txt',
#  'test15_9.txt.txt',
#  'test26_15.txt.txt',
#  'test26_22.txt.txt',
#  'test27_17.txt.txt',
#  'test27_21.txt.txt',
#  'test27_9.txt.txt',
#  'test2_23.txt.txt',
#  'test4_47.txt.txt',
#  'test_30.txt.txt',
#  'test_37.txt.txt']

# %%
import os

label_dir = r"C:\Users\shell\OneDrive\Desktop\accident_detection\dataset\labels\train"

for f in os.listdir(label_dir):
    if f.endswith(".txt.txt"):
        old_path = os.path.join(label_dir, f)
        new_path = os.path.join(label_dir, f.replace(".xml.txt", ".txt"))
        os.rename(old_path, new_path)

print("Renaming done!")
# Out:
# Renaming done!

# %%
import os
os.listdir(r"C:\Users\shell\OneDrive\Desktop\accident_detection\dataset\labels\train")
# Out:
# ['acc1 (1).txt',
#  'acc1 (15).txt',
#  'acc1 (2).txt',
#  'acc1 (3).txt',
#  'acc1 (5).txt',
#  'test10_10.xml.txt',
#  'test10_11.xml.txt',
#  'test10_12.xml.txt',
#  'test10_13.xml.txt',
#  'test10_14.xml.txt',
#  'test10_15.xml.txt',
#  'test10_16.xml.txt',
#  'test10_17.xml.txt',
#  'test10_18.txt',
#  'test10_19.txt',
#  'test10_20.txt',
#  'test10_21.txt',
#  'test10_24.txt',
#  'test10_25.txt',
#  'test10_26.txt',
#  'test10_28.txt',
#  'test10_29.txt',
#  'test10_30.txt',
#  'test10_31.txt',
#  'test10_32.txt',
#  'test10_35.txt',
#  'test10_37.txt',
#  'test10_38.txt',
#  'test10_39.txt',
#  'test10_40.txt',
#  'test10_41.txt',
#  'test10_42.txt',
#  'test10_43.txt',
#  'test10_44.txt',
#  'test10_45.txt',
#  'test10_47.txt',
#  'test10_48.txt',
#  'test10_49.txt',
#  'test10_50.txt',
#  'test10_51.txt',
#  'test10_52.txt',
#  'test10_53.txt',
#  'test10_55.txt',
#  'test10_57.txt',
#  'test10_58.txt',
#  'test10_59.txt',
#  'test10_60.txt',
#  'test10_9.xml.txt',
# ...
