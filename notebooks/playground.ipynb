# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11n.pt")

# %%
train_results = model.train(
    data = "C:/Users/shell/OneDrive/Desktop/accident_detection/dataset/data.yaml",
    epochs = 120,
    imgsz = 640,
    batch = 8,
    device = 0,
    project="C:/Users/shell/OneDrive/Desktop/accident_detection/runs",
    name="accident_train_v1"
)
# Out:
# Ultralytics 8.4.13  Python-3.11.1 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
from ultralytics import YOLO
my_model = YOLO("C:/Users/shell/OneDrive/Desktop/accident_detection/runs/accident_train_v1/weights/best.pt")

# %%
prediction = model(r"C:\Users\shell\OneDrive\Desktop\accident_detection\dataset\test\images\test26_23.jpg")
prediction[0].show()
# Out:
# image 1/1 C:\Users\shell\OneDrive\Desktop\accident_detection\dataset\test\images\test26_23.jpg: 384x640 2 accidents, 38.0ms
# Speed: 7.0ms preprocess, 38.0ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
